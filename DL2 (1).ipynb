# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from tensorflow.keras.utils import to_categorical
import matplotlib.pyplot as plt

# %%
url = "https://archive.ics.uci.edu/ml/machine-learning-databases/letter-recognition/letter-recognition.data"
columns = ['letter', 'x-box', 'y-box', 'width', 'high', 'onpix', 'x-bar', 'y-bar', 'x2bar', 'y2bar',
           'xybar', 'x2ybr', 'xy2br', 'x-ege', 'xegvy', 'y-ege', 'yegvx']
df = pd.read_csv(url, header=None, names=columns)

# %%
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(df['letter'])
y_categorical = to_categorical(y_encoded)

# %%
X = df.drop('letter', axis=1).values

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_categorical, test_size=0.2, random_state=42)

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Dense(128, input_shape=(X_train.shape[1],), activation='relu'),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(26, activation='softmax')
])
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
history = model.fit(X_train, y_train, epochs=20, batch_size=32, validation_split=0.1, verbose=1)
# Out:
# Epoch 1/20
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.4303 - loss: 2.1691 - val_accuracy: 0.7638 - val_loss: 0.8429
# Epoch 2/20
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7845 - loss: 0.7348 - val_accuracy: 0.8250 - val_loss: 0.5952
# Epoch 3/20
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8459 - loss: 0.5316 - val_accuracy: 0.8669 - val_loss: 0.4679
# Epoch 4/20
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.8777 - loss: 0.4151 - val_accuracy: 0.8850 - val_loss: 0.3971
# Epoch 5/20
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8982 - loss: 0.3526 - val_accuracy: 0.9038 - val_loss: 0.3477
# Epoch 6/20
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9119 - loss: 0.3058 - val_accuracy: 0.9112 - val_loss: 0.3088
# Epoch 7/20
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9119 - loss: 0.2833 - val_accuracy: 0.9175 - val_loss: 0.2845
# Epoch 8/20
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9233 - loss: 0.2520 - val_accuracy: 0.9250 - val_loss: 0.2512
# Epoch 9/20
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9355 - loss: 0.2087 - val_accuracy: 0.9281 - val_loss: 0.2480
# Epoch 10/20
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9449 - loss: 0.1882 - val_accuracy: 0.9331 - val_loss: 0.2262
# Epoch 11/20
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9472 - loss: 0.1749 - val_accuracy: 0.9444 - val_loss: 0.1992
# Epoch 12/20
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9487 - loss: 0.1672 - val_accuracy: 0.9413 - val_loss: 0.1954
# Epoch 13/20
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9551 - loss: 0.1471 - val_accuracy: 0.9413 - val_loss: 0.1933
# Epoch 14/20
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9604 - loss: 0.1312 - val_accuracy: 0.9400 - val_loss: 0.1830
# Epoch 15/20
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9583 - loss: 0.1325 - val_accuracy: 0.9475 - val_loss: 0.1653
# Epoch 16/20
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9622 - loss: 0.1227 - val_accuracy: 0.9488 - val_loss: 0.1692
# Epoch 17/20
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9664 - loss: 0.1086 - val_accuracy: 0.9506 - val_loss: 0.1571
# Epoch 18/20
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9709 - loss: 0.0991 - val_accuracy: 0.9475 - val_loss: 0.1671
# Epoch 19/20
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9746 - loss: 0.0878 - val_accuracy: 0.9500 - val_loss: 0.1653
# Epoch 20/20
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9759 - loss: 0.0830 - val_accuracy: 0.9538 - val_loss: 0.1626

# %%
loss, accuracy = model.evaluate(X_test, y_test)
print(f"\nTest Accuracy: {accuracy:.2f}")
# Out:
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9463 - loss: 0.1694
#
# Test Accuracy: 0.95

# %%
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Acc')
plt.plot(history.history['val_accuracy'], label='Val Acc')
plt.title('Model Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# %%
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.title('Model Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()
